# %% [markdown]
# # Gráfico de relação dimensões x tempo

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

# %% [markdown]
# ## Liguagem C

# %%
data = pd.read_csv('output\dados_1.csv', delimiter=';')
data1 = data.iloc[::10,:]
data1.head()
# Out:
#       x    y  tempo  invert
# 0     1    1  0.000       1
# 10  101  101  0.000       1
# 20  201  201  0.000       1
# 30  301  301  0.000       1
# 40  401  401  0.004       1

# %%
data = pd.read_csv('output\dados_0.csv', delimiter=';')
data2 = data.iloc[::10,:]
data2.head()
# Out:
#       x    y  tempo  invert
# 0     1    1    0.0       0
# 10  101  101    0.0       0
# 20  201  201    0.0       0
# 30  301  301    0.0       0
# 40  401  401    0.0       0

# %%
fig = plt.figure(figsize=(10, 8))

plt.scatter(data1['x'], data1['tempo'], c='r', marker='.')
plt.scatter(data2['x'], data2['tempo'], c='b', marker='.')

plt.xlabel('A[x][x]')
plt.ylabel('Tempo')
plt.show()

# %% [markdown]
# ## Liguagem Fortran

# %%
data = pd.read_csv('output\dados_fortran_inverso.csv', delimiter=';')
data1 = data.sort_values(by=['tempo'])
data1.head()
# Out:
#        x      y  tempo  inverso
# 0    100    100   0.00        0
# 2   1000   1000   0.01        0
# 3   2000   2000   0.09        0
# 1  10000  10000   2.89        0
# 4  22900  22900   9.41        0

# %%
data = pd.read_csv('output\dados_fortran_naoInverso.csv', delimiter=';')
data2 = data.sort_values(by=['tempo'])
data2.head()
# Out:
#        x      y  tempo  inverso
# 0    100    100   0.00        1
# 3   9000   9000   0.79        1
# 1  10000  10000   1.23        1
# 4  11000  11000   1.36        1
# 5  12000  12000   1.93        1

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data1['x'], data1['y'], data1['tempo'], c='r', marker='o')
ax.scatter(data2['x'], data2['y'], data2['tempo'], c='b', marker='o')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Tempo')
plt.show()
