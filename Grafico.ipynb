# %% [markdown]
# # Gráfico de relação dimensões x tempo

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

# %% [markdown]
# ## Liguagem C

# %%
data = pd.read_csv('output\dados_naoInverso.csv', delimiter=';')
data1 = data.sort_values(by=['tempo'])
data1.head()
# Out:
#       x     y  tempo  inverso
# 0   100   100  0.000        1
# 9   156   156  0.000        1
# 8   312   312  0.001        1
# 7   625   625  0.002        1
# 6  1250  1250  0.005        1

# %%
data = pd.read_csv('output\dados_inverso.csv', delimiter=';')
data2 = data.sort_values(by=['tempo'])
data2.head()
# Out:
#        x     y  tempo  inverso
# 0    100   100  0.000        0
# 18   156   156  0.000        0
# 19   625   625  0.001        0
# 1   1000  1000  0.008        0
# 20  1625  1625  0.009        0

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data1['x'], data1['y'], data1['tempo'], c='r', marker='o')
ax.scatter(data2['x'], data2['y'], data2['tempo'], c='b', marker='o')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Tempo')
plt.show()

# %% [markdown]
# ## Liguagem Fortran

# %%
data = pd.read_csv('output\dados_fortran_inverso.csv', delimiter=';')
data1 = data.sort_values(by=['tempo'])
data1.head()
# Out:
#        x      y  tempo  inverso
# 0    100    100   0.00        0
# 2   1000   1000   0.01        0
# 3   2000   2000   0.09        0
# 1  10000  10000   2.89        0
# 4  22900  22900   9.41        0

# %%
data = pd.read_csv('output\dados_fortran_naoInverso.csv', delimiter=';')
data2 = data.sort_values(by=['tempo'])
data2.head()
# Out:
#        x      y  tempo  inverso
# 0    100    100   0.00        1
# 3   9000   9000   0.79        1
# 1  10000  10000   1.23        1
# 4  11000  11000   1.36        1
# 5  12000  12000   1.93        1

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data1['x'], data1['y'], data1['tempo'], c='r', marker='o')
ax.scatter(data2['x'], data2['y'], data2['tempo'], c='b', marker='o')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Tempo')
plt.show()
